# %%
import pandas as pd
import requests
import json
import numpy as np

# %%
liste=["Mont Saint Michel",
"St Malo",
"Bayeux",
"Le Havre",
"Rouen",
"Paris",
"Amiens",
"Lille",
"Strasbourg",
"Chateau du Haut Koenigsbourg",
"Colmar",
"Eguisheim",
"Besancon",
"Dijon",
"Annecy",
"Grenoble",
"Lyon",
"Gorges du Verdon",
"Bormes les Mimosas",
"Cassis",
"Marseille",
"Aix en Provence",
"Avignon",
"Uzes",
"Nimes",
"Aigues Mortes",
"Saintes Maries de la mer",
"Collioure",
"Carcassonne",
"Ariege",
"Toulouse",
"Montauban",
"Biarritz",
"Bayonne",
"La Rochelle"]

# %%
liste= [item.replace(" ", "+") for item in liste]

# %%
data = pd.DataFrame()
data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in liste:
    # Make a request
    r = requests.get("https://nominatim.openstreetmap.org/search?q={}&adress-details=1&format=json".format(i))
    # Store it in our DataFrame
    data = data.append(r.json()[0], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-5-4506033d2611> in <module>
#       3     r = requests.get("https://nominatim.openstreetmap.org/search?q={}&adress-details=1&format=json".format(i))
#       4     # Store it in our DataFrame
# ----> 5     data = data.append(r.json()[0], ignore_index=True)
#
# /opt/conda/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# /opt/conda/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# /opt/conda/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/conda/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
mycolumns=['display_name','lat','lon']
data_1=data[mycolumns]

data_first_cities=data_1.iloc[0:9,:]
data_first_cities
# Out:
#                                         display_name         lat  \
# 0  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...  48.6359541
# 1  St. Malo, De Salaberry, Manitoba, R0A 1T0, Canada   49.314695
# 2  Bayeux, Calvados, Normandie, France métropolit...  49.2764624
# 3  Le Havre, Seine-Maritime, Normandie, France mé...  49.4938975
# 4  Rouen, Seine-Maritime, Normandie, France métro...  49.4404591
# 5  Paris, Île-de-France, France métropolitaine, F...  48.8588897
# 6  Amiens, Somme, Hauts-de-France, France métropo...  49.8941708
# 7  Lille, Nord, Hauts-de-France, France métropoli...  50.6365654
# 8  Strasbourg, Bas-Rhin, Grand Est, France métrop...   48.584614
#
#                   lon
# 0  -1.511459954959514
# 1         -96.9538228
# 2          -0.7024738
# 3           0.1079732
# 4           1.0939658
# 5  2.3200410217200766
# 6           2.2956951
# 7           3.0635282
# 8           7.7507127

# %%
mycolumns=['display_name','lat','lon']
data_1=data[mycolumns]

# %%
data_1
# Out:
#                                          display_name                 lat  \
# 0   Mont Saint-Michel, Le Mont-Saint-Michel, Avran...          48.6359541
# 1   St. Malo, De Salaberry, Manitoba, R0A 1T0, Canada           49.314695
# 2   Bayeux, Calvados, Normandie, France métropolit...          49.2764624
# 3   Le Havre, Seine-Maritime, Normandie, France mé...          49.4938975
# 4   Rouen, Seine-Maritime, Normandie, France métro...          49.4404591
# 5   Paris, Île-de-France, France métropolitaine, F...          48.8588897
# 6   Amiens, Somme, Hauts-de-France, France métropo...          49.8941708
# 7   Lille, Nord, Hauts-de-France, France métropoli...          50.6365654
# 8   Strasbourg, Bas-Rhin, Grand Est, France métrop...           48.584614
# 9   Château du Haut-Kœnigsbourg, Chemin fermé suit...  48.249489800000006
# 10  Colmar, Colmar-Ribeauvillé, Haut-Rhin, Grand E...          48.0777517
# 11  Eguisheim, Colmar-Ribeauvillé, Haut-Rhin, Gran...          48.0447968
# 12  Besancon, Weybridge Park, Nelson Mandela Bay W...         -33.9659325
# 13  Dijon, Côte-d'Or, Bourgogne-Franche-Comté, Fra...          47.3215806
# 14  Annecy, Haute-Savoie, Auvergne-Rhône-Alpes, Fr...          45.8992348
# 15  Grenoble, Isère, Auvergne-Rhône-Alpes, France ...          45.1875602
# 16  Lyon, Métropole de Lyon, Circonscription dépar...          45.7578137
# 17  Gorges du Verdon, La Palud-sur-Verdon, Castell...             43.7497
# 18  Bormes-les-Mimosas, Toulon, Var, Provence-Alpe...          43.1506968
#
#                    lon
# 0   -1.511459954959514
# 1          -96.9538228
# 2           -0.7024738
# 3            0.1079732
# 4            1.0939658
# 5   2.3200410217200766
# 6            2.2956951
# 7            3.0635282
# 8            7.7507127
# 9     7.34429620253195
# 10           7.3579641
# 11           7.3079618
# 12          25.5080179
# 13           5.0414701
# 14           6.1288847
# 15           5.7357819
# 16           4.8320114
# 17             6.32859
# 18           6.3419285

# %% [markdown]
# exemple = data_first_cities['display_name'][0]
# exemple

# %%
data_1['display_name']=data_1['display_name'].apply(lambda x : x.split(',')[0])
# Out:
# <ipython-input-9-6e21b1afdd2c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_1['display_name']=data_1['display_name'].apply(lambda x : x.split(',')[0])

# %%
data_1
# Out:
#                    display_name                 lat                 lon
# 0             Mont Saint-Michel          48.6359541  -1.511459954959514
# 1                      St. Malo           49.314695         -96.9538228
# 2                        Bayeux          49.2764624          -0.7024738
# 3                      Le Havre          49.4938975           0.1079732
# 4                         Rouen          49.4404591           1.0939658
# 5                         Paris          48.8588897  2.3200410217200766
# 6                        Amiens          49.8941708           2.2956951
# 7                         Lille          50.6365654           3.0635282
# 8                    Strasbourg           48.584614           7.7507127
# 9   Château du Haut-Kœnigsbourg  48.249489800000006    7.34429620253195
# 10                       Colmar          48.0777517           7.3579641
# 11                    Eguisheim          48.0447968           7.3079618
# 12                     Besancon         -33.9659325          25.5080179
# 13                        Dijon          47.3215806           5.0414701
# 14                       Annecy          45.8992348           6.1288847
# 15                     Grenoble          45.1875602           5.7357819
# 16                         Lyon          45.7578137           4.8320114
# 17             Gorges du Verdon             43.7497             6.32859
# 18           Bormes-les-Mimosas          43.1506968           6.3419285

# %% [markdown]
# data_1['lat']=data_1['lat'].astype(float)
# data_1['lat']=round(data_1['lat'],2)
#
# data_1['lon']=data_1['lon'].astype(float)
# data_1['lon']=round(data_1['lon'],2)

# %%
data_2=pd.DataFrame()
data_2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data_lat=data_1.iloc[:,1]
data_lon=data_1.iloc[:,2]

# %%
param = {'lat':data_lat[0] , 
         'lon':data_lon[0], 
         "exclude": "current,minutely,hourly",
        "units": "metric",
        "appid": '93e1b4d146758830ad3bc42c9a16aeed'
}

# %%
len(data_lon)
# Out:
# 19

# %%
temperature=[]
for index in range(len(data_lon)):
    param = {'lat':data_lat[index] , 
         'lon':data_lon[index], 
         "exclude": "current,minutely,hourly",
        "units": "metric",
        "appid": '93e1b4d146758830ad3bc42c9a16aeed'}
    
    r= requests.get('https://api.openweathermap.org/data/2.5/onecall', param)
    
    temp=[]
    for i in range (0,7):
        r3=r.json()['daily'][i]['temp']['day']
        temp.append(r3)

    temperature.append(np.mean(temp))

# %%
print(temperature)
# Out:
# [15.247142857142858, 8.81, 14.564285714285717, 14.194285714285714, 14.348571428571429, 15.807142857142855, 14.365714285714285, 14.785714285714283, 15.328571428571427, 12.97857142857143, 16.038571428571426, 16.09142857142857, 21.30428571428572, 14.959999999999999, 14.955714285714285, 18.41142857142857, 16.75142857142857, 15.45142857142857, 18.247142857142858]

# %%
data_1['temperature']=temperature
# Out:
# <ipython-input-17-75b5a73bd0b1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_1['temperature']=temperature

# %%
data_1.to_csv('temp_cities.csv')

# %%
city_Amiens=pd.read_json('hotels_Amiens.json')

# %%
city_Aigues_Mortes=pd.read_json('hotels_Aigues-Mortes.json')
liste_Aigues_Mortes= city_Aigues_Mortes.iloc[:25]
liste_Aigues_Mortes['city']='Aigues-Mortes'

city_Aix_en_Provence=pd.read_json('hotels_Aix-en-Provence.json')
liste_Aix_en_Provence= city_Aix_en_Provence.iloc[:25]
liste_Aix_en_Provence['city']='Aix-en-Provence'

city_Amiens=pd.read_json('hotels_Amiens.json')
liste_Amiens= city_Amiens.iloc[:25]
liste_Amiens['city']='Amiens'

city_Annecy=pd.read_json('hotels_Annecy.json')
liste_Annecy= city_Annecy.iloc[:25]
liste_Annecy['city']='Annecy'

city_Ariege=pd.read_json('hotels_Ariege.json')
liste_Ariege= city_Ariege.iloc[:25]
liste_Ariege['city']='Ariege'

city_Avignon=pd.read_json('hotels_Avignon.json')
liste_Avignon= city_Avignon.iloc[:25]
liste_Avignon['city']='Avignon'

city_Bayeux=pd.read_json('hotels_Bayeux.json')
liste_Bayeux= city_Bayeux.iloc[:25]
liste_Bayeux['city']='Bayeux'

city_Bayonne=pd.read_json('hotels_Bayonne.json')
liste_Bayonne= city_Bayonne.iloc[:25]
liste_Bayonne['city']='Bayonne'

city_Besancon=pd.read_json('hotels_Besancon.json')
liste_Besancon= city_Besancon.iloc[:25]
liste_Besancon['city']='Besancon'

city_Biarritz=pd.read_json('hotels_Biarritz.json')
liste_Biarritz= city_Biarritz.iloc[:25]
liste_Biarritz['city']='Biarritz'

city_Bormes_les_Mimosas=pd.read_json('hotels_Bormes-les-Mimosas.json')
liste_Bormes_les_Mimosas= city_Bormes_les_Mimosas.iloc[:25]
liste_Bormes_les_Mimosas['city']='Bormes-les-Mimosas'

city_Carcassonne=pd.read_json('hotels_Carcassonne.json')
liste_Carcassonne= city_Carcassonne.iloc[:25]
liste_Carcassonne['city']='Carcassonne'

city_Cassis=pd.read_json('hotels_Cassis.json')
liste_Cassis= city_Cassis.iloc[:25]
liste_Cassis['city']='Cassis'

city_Chateau_du_Haut_Koenigsbourg=pd.read_json('hotels_Chateau-du-Haut-Koenigsbourg.json')
liste_Chateau_du_Haut_Koenigsbourg= city_Chateau_du_Haut_Koenigsbourg.iloc[:25]
liste_Chateau_du_Haut_Koenigsbourg['city']='Chateau-du-Haut-Koenigsbourg'

city_Collioure=pd.read_json('hotels_Collioure.json')
liste_Collioure= city_Collioure.iloc[:25]
liste_Collioure['city']='Collioure'

city_Colmar=pd.read_json('hotels_Colmar.json')
liste_Colmar= city_Colmar.iloc[:25]
liste_Colmar['city']='Colmar'

city_Dijon=pd.read_json('hotels_Dijon.json')
liste_Dijon= city_Dijon.iloc[:25]
liste_Dijon['city']='Dijon'

city_Eguisheim=pd.read_json('hotels_Eguisheim.json')
liste_Eguisheim= city_Eguisheim.iloc[:25]
liste_Eguisheim['city']='Eguisheim'

city_Gorges_du_Verdon=pd.read_json('hotels_Gorges-du-Verdon.json')
liste_Gorges_du_Verdon= city_Gorges_du_Verdon.iloc[:25]
liste_Gorges_du_Verdon['city']='Gorges-du-Verdon'

city_Grenoble=pd.read_json('hotels_Grenoble.json')
liste_Grenoble= city_Grenoble.iloc[:25]
liste_Grenoble['city']='Grenoble'

city_La_Rochelle=pd.read_json('hotels_La-Rochelle.json')
liste_La_Rochelle= city_La_Rochelle.iloc[:25]
liste_La_Rochelle['city']='La-Rochelle'

city_Le_Havre=pd.read_json('hotels_Le-Havre.json')
liste_Le_Havre= city_Le_Havre.iloc[:25]
liste_Le_Havre['city']='Le-Havre'

city_Lille=pd.read_json('hotels_Lille.json')
liste_Lille= city_Lille.iloc[:25]
liste_Lille['city']='Lille'

city_Lyon=pd.read_json('hotels_Lyon.json')
liste_Lyon= city_Lyon.iloc[:25]
liste_Lyon['city']='Lyon'

city_Marseille=pd.read_json('hotels_Marseille.json')
liste_Marseille= city_Marseille.iloc[:25]
liste_Marseille['city']='Marseille'

city_Mont_Saint_Michel=pd.read_json('hotels_Mont-Saint-Michel.json')
liste_Mont_Saint_Michel= city_Mont_Saint_Michel.iloc[:25]
liste_Mont_Saint_Michel['city']='Mont-Saint-Michel'

city_Montauban=pd.read_json('hotels_Montauban.json')
liste_Montauban= city_Montauban.iloc[:25]
liste_Montauban['city']='Montauban'

city_Nimes=pd.read_json('hotels_Nimes.json')
liste_Nimes= city_Nimes.iloc[:25]
liste_Nimes['city']='Nimes'

city_Paris=pd.read_json('hotels_Paris.json')
liste_Paris= city_Paris.iloc[:25]
liste_Paris['city']='Paris'

city_Rouen=pd.read_json('hotels_Rouen.json')
liste_Rouen= city_Rouen.iloc[:25]
liste_Rouen['city']='Rouen'

city_Saintes_Maries_de_la_mer=pd.read_json('hotels_Saintes-Maries-de-la-mer.json')
liste_Saintes_Maries_de_la_mer= city_Saintes_Maries_de_la_mer.iloc[:25]
liste_Saintes_Maries_de_la_mer['city']='Saintes-Maries-de-la-mer'

city_St_Malo=pd.read_json('hotels_St-Malo.json')
liste_St_Malo= city_St_Malo.iloc[:25]
liste_St_Malo['city']='St-Malo'

city_Strasbourg=pd.read_json('hotels_Strasbourg.json')
liste_Strasbourg= city_Strasbourg.iloc[:25]
liste_Strasbourg['city']='Strasbourg'

city_Toulouse=pd.read_json('hotels_Toulouse.json')
liste_Toulouse= city_Toulouse.iloc[:25]
liste_Toulouse['city']='Toulouse'

city_Uzes=pd.read_json('hotels_Uzes.json')
liste_Uzes= city_Uzes.iloc[:25]
liste_Uzes['city']='Uzes'
# Out:
# <ipython-input-20-489cabdfe347>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Aigues_Mortes['city']='Aigues-Mortes'
# <ipython-input-20-489cabdfe347>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Aix_en_Provence['city']='Aix-en-Provence'
# <ipython-input-20-489cabdfe347>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Amiens['city']='Amiens'
# <ipython-input-20-489cabdfe347>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Annecy['city']='Annecy'
# <ipython-input-20-489cabdfe347>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Ariege['city']='Ariege'
# <ipython-input-20-489cabdfe347>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Avignon['city']='Avignon'
# <ipython-input-20-489cabdfe347>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Bayeux['city']='Bayeux'
# <ipython-input-20-489cabdfe347>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Bayonne['city']='Bayonne'
# <ipython-input-20-489cabdfe347>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Besancon['city']='Besancon'
# <ipython-input-20-489cabdfe347>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Biarritz['city']='Biarritz'
# <ipython-input-20-489cabdfe347>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Bormes_les_Mimosas['city']='Bormes-les-Mimosas'
# <ipython-input-20-489cabdfe347>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Carcassonne['city']='Carcassonne'
# <ipython-input-20-489cabdfe347>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Cassis['city']='Cassis'
# <ipython-input-20-489cabdfe347>:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Chateau_du_Haut_Koenigsbourg['city']='Chateau-du-Haut-Koenigsbourg'
# <ipython-input-20-489cabdfe347>:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Collioure['city']='Collioure'
# <ipython-input-20-489cabdfe347>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Colmar['city']='Colmar'
# <ipython-input-20-489cabdfe347>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Dijon['city']='Dijon'
# <ipython-input-20-489cabdfe347>:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Eguisheim['city']='Eguisheim'
# <ipython-input-20-489cabdfe347>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Gorges_du_Verdon['city']='Gorges-du-Verdon'
# <ipython-input-20-489cabdfe347>:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Grenoble['city']='Grenoble'
# <ipython-input-20-489cabdfe347>:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_La_Rochelle['city']='La-Rochelle'
# <ipython-input-20-489cabdfe347>:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Le_Havre['city']='Le-Havre'
# <ipython-input-20-489cabdfe347>:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Lille['city']='Lille'
# <ipython-input-20-489cabdfe347>:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Lyon['city']='Lyon'
# <ipython-input-20-489cabdfe347>:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Marseille['city']='Marseille'
# <ipython-input-20-489cabdfe347>:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Mont_Saint_Michel['city']='Mont-Saint-Michel'
# <ipython-input-20-489cabdfe347>:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Montauban['city']='Montauban'
# <ipython-input-20-489cabdfe347>:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Nimes['city']='Nimes'
# <ipython-input-20-489cabdfe347>:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Paris['city']='Paris'
# <ipython-input-20-489cabdfe347>:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Rouen['city']='Rouen'
# <ipython-input-20-489cabdfe347>:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Saintes_Maries_de_la_mer['city']='Saintes-Maries-de-la-mer'
# <ipython-input-20-489cabdfe347>:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_St_Malo['city']='St-Malo'
# <ipython-input-20-489cabdfe347>:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Strasbourg['city']='Strasbourg'
# <ipython-input-20-489cabdfe347>:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Toulouse['city']='Toulouse'
# <ipython-input-20-489cabdfe347>:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liste_Uzes['city']='Uzes'

# %%
hotels=[liste_Aigues_Mortes, liste_Aix_en_Provence, liste_Amiens,liste_Annecy, liste_Ariege, liste_Avignon, liste_Bayeux, liste_Bayonne, liste_Besancon, liste_Biarritz, liste_Bormes_les_Mimosas, liste_Carcassonne, liste_Cassis,liste_Chateau_du_Haut_Koenigsbourg, liste_Collioure, liste_Colmar, liste_Dijon, liste_Eguisheim, liste_Gorges_du_Verdon, liste_Grenoble, liste_La_Rochelle, liste_Le_Havre, liste_Lille, liste_Lyon, liste_Marseille, liste_Mont_Saint_Michel, liste_Montauban, liste_Nimes, liste_Paris, liste_Rouen, liste_Saintes_Maries_de_la_mer, liste_St_Malo, liste_Strasbourg, liste_Toulouse, liste_Uzes]

# %%
hotels=pd.concat(hotels)
display(hotels)
# Out:
#                                         name  \
# 0          \nRésidence Odalys Fleur de Sel\n
# 1              \nHotel Canal Aigues Mortes\n
# 2                   \nMaison des Croisades\n
# 3   \nRésidence Odalys Le Mas des Flamants\n
# 4                      \nHôtel Saint Louis\n
# ..                                       ...
# 20                            \nLa Taverne\n
# 21                            \nLes cèdres\n
# 22               \nLa Petite Maison - Uzes\n
# 23                \nLa Closerie du Château\n
# 24                                \nMa Lou\n
#
#                                                   url  \
# 0   https://www.booking.com\n/hotel/fr/residence-o...
# 1   https://www.booking.com\n/hotel/fr/canal-aigue...
# 2   https://www.booking.com\n/hotel/fr/des-croisad...
# 3   https://www.booking.com\n/hotel/fr/residence-l...
# 4   https://www.booking.com\n/hotel/fr/saint-louis...
# ..                                                ...
# 20  https://www.booking.com\n/hotel/fr/la-taverne....
# 21  https://www.booking.com\n/hotel/fr/les-cedres-...
# 22  https://www.booking.com\n/hotel/fr/la-petite-m...
# 23  https://www.booking.com\n/hotel/fr/villa-la-cl...
# 24  https://www.booking.com\n/hotel/fr/ma-lou-uzes...
#
#                                coords  score  \
# 0                  4.179246,43.574094   8,3
# 1   4.19482469558716,43.5729875200846   8,6
# 2         4.18829819999996,43.5689974   8,9
# 3   4.18062186221505,43.5737943531084   8,0
# 4   4.18934360146523,43.5672196715711   8,5
# ..                                ...    ...
# 20                4.4200515,44.014659   8,8
# 21     4.414136186178,44.011847405338   9,5
# 22                4.4177517,44.010658   None
# 23                4.391819,44.0022962   None
# 24               4.4180049,44.0098724   None
#
#                                           description           city
# 0   \nSitué à Aigues-Mortes, à 5 minutes à pied du...  Aigues-Mortes
# 1   \nL’hôtel Canal Aigues Mortes vous accueille s...  Aigues-Mortes
# 2   \nSituée à Aigues-Mortes, la Maison des Croisa...  Aigues-Mortes
# 3   \nSituée à l'extérieur des fortifications d'Ai...  Aigues-Mortes
# 4   \nDoté d’un spa et d’un restaurant, l’Hôtel Sa...  Aigues-Mortes
# ..                                                ...            ...
# 20  \nL'établissement La Taverne est situé à Uzès,...           Uzes
# 21  \nL'établissement Les cèdres est situé à Uzès....           Uzes
# 22  \nLa Petite Maison - Uzes is set in Uzès. Gues...           Uzes
# 23  \nVilla La Closerie du Château provides accomm...           Uzes
# 24  \nSitué à Uzès, le Ma Lou propose un hébergeme...           Uzes
#
# [875 rows x 6 columns]

# %%
display(hotels.iloc[:, ::-1])
# Out:
#              city                                        description  score  \
# 0   Aigues-Mortes  \nSitué à Aigues-Mortes, à 5 minutes à pied du...   8,3
# 1   Aigues-Mortes  \nL’hôtel Canal Aigues Mortes vous accueille s...   8,6
# 2   Aigues-Mortes  \nSituée à Aigues-Mortes, la Maison des Croisa...   8,9
# 3   Aigues-Mortes  \nSituée à l'extérieur des fortifications d'Ai...   8,0
# 4   Aigues-Mortes  \nDoté d’un spa et d’un restaurant, l’Hôtel Sa...   8,5
# ..            ...                                                ...    ...
# 20           Uzes  \nL'établissement La Taverne est situé à Uzès,...   8,8
# 21           Uzes  \nL'établissement Les cèdres est situé à Uzès....   9,5
# 22           Uzes  \nLa Petite Maison - Uzes is set in Uzès. Gues...   None
# 23           Uzes  \nVilla La Closerie du Château provides accomm...   None
# 24           Uzes  \nSitué à Uzès, le Ma Lou propose un hébergeme...   None
#
#                                coords  \
# 0                  4.179246,43.574094
# 1   4.19482469558716,43.5729875200846
# 2         4.18829819999996,43.5689974
# 3   4.18062186221505,43.5737943531084
# 4   4.18934360146523,43.5672196715711
# ..                                ...
# 20                4.4200515,44.014659
# 21     4.414136186178,44.011847405338
# 22                4.4177517,44.010658
# 23                4.391819,44.0022962
# 24               4.4180049,44.0098724
#
#                                                   url  \
# 0   https://www.booking.com\n/hotel/fr/residence-o...
# 1   https://www.booking.com\n/hotel/fr/canal-aigue...
# 2   https://www.booking.com\n/hotel/fr/des-croisad...
# 3   https://www.booking.com\n/hotel/fr/residence-l...
# 4   https://www.booking.com\n/hotel/fr/saint-louis...
# ..                                                ...
# 20  https://www.booking.com\n/hotel/fr/la-taverne....
# 21  https://www.booking.com\n/hotel/fr/les-cedres-...
# 22  https://www.booking.com\n/hotel/fr/la-petite-m...
# 23  https://www.booking.com\n/hotel/fr/villa-la-cl...
# 24  https://www.booking.com\n/hotel/fr/ma-lou-uzes...
#
#                                         name
# 0          \nRésidence Odalys Fleur de Sel\n
# 1              \nHotel Canal Aigues Mortes\n
# 2                   \nMaison des Croisades\n
# 3   \nRésidence Odalys Le Mas des Flamants\n
# 4                      \nHôtel Saint Louis\n
# ..                                       ...
# 20                            \nLa Taverne\n
# 21                            \nLes cèdres\n
# 22               \nLa Petite Maison - Uzes\n
# 23                \nLa Closerie du Château\n
# 24                                \nMa Lou\n
#
# [875 rows x 6 columns]

# %%
hotels.to_csv('hotels.csv')
